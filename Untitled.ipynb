# %%
# !pip install PyWavelets

# %%
import numpy as np
import matplotlib.pyplot as plt

import pywt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import matplotlib.style as style 
# style.use('ggplot')
X_train = pd.read_csv("./X_train.csv")
y_train = pd.read_csv("./y_train.csv")
X_test = pd.read_csv('./X_test.csv')

# %%
plt.plot(np.array(X_train.angular_velocity_X.values)[:64])

# %%
coef.shape
# Out:
# (99, 128)

# %%
scales = np.arange(1,100)

# %%
coef , freq = pywt.cwt(np.array(X_train.angular_velocity_Y.values)[0:128], scales, wavelet='gaus1')
plt.imshow(abs(coef))

# %%
coef , freq = pywt.cwt(np.array(X_train.angular_velocity_Y.values)[128:256], scales, wavelet='gaus1')
plt.imshow(abs(coef))

# %%
coef , freq = pywt.cwt(np.array(X_train.orientation_X.values)[128:256], scales, wavelet='gaus1')
plt.imshow(abs(coef))

# %%
y_train
# Out:
#       series_id  group_id        surface
# 0             0        13  fine_concrete
# 1             1        31       concrete
# 2             2        20       concrete
# 3             3        31       concrete
# 4             4        22     soft_tiles
# ...         ...       ...            ...
# 3805       3805        55          tiled
# 3806       3806        67           wood
# 3807       3807        48  fine_concrete
# 3808       3808        54          tiled
# 3809       3809        56       soft_pvc
#
# [3810 rows x 3 columns]

# %%
256+128
# Out:
# 384
