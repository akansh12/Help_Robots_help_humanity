# %%
import os
import gc
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import tools
import plotly.offline as py
py.init_notebook_mode(connected=True)
from sklearn import metrics
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation, MaxPooling1D
from keras.layers import Conv1D
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer, LabelEncoder
import plotly.graph_objs as go
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
gc.collect()
plt.rcParams['figure.figsize'] = [20, 8]
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/X_train.csv')
y = pd.read_csv('../input/y_train.csv')
test = pd.read_csv('../input/X_test.csv')
ss = pd.read_csv('../input/sample_submission.csv')

# %%
tmp = dict(zip(y.series_id, y.surface))
train['target'] = train['series_id'].map(tmp)
train.head()
train.head()
# Out:
#   row_id  series_id      ...        linear_acceleration_Z         target
# 0    0_0          0      ...                      -9.7532  fine_concrete
# 1    0_1          0      ...                      -9.4128  fine_concrete
# 2    0_2          0      ...                      -8.7267  fine_concrete
# 3    0_3          0      ...                     -10.0960  fine_concrete
# 4    0_4          0      ...                     -10.4410  fine_concrete
#
# [5 rows x 14 columns]

# %%
train.head()
# Out:
#   row_id  series_id      ...        linear_acceleration_Z         target
# 0    0_0          0      ...                      -9.7532  fine_concrete
# 1    0_1          0      ...                      -9.4128  fine_concrete
# 2    0_2          0      ...                      -8.7267  fine_concrete
# 3    0_3          0      ...                     -10.0960  fine_concrete
# 4    0_4          0      ...                     -10.4410  fine_concrete
#
# [5 rows x 14 columns]

# %%
le = LabelBinarizer()
lb = LabelEncoder()
target = le.fit_transform(y['surface'])
target = np.array(target)
y['s']=lb.fit_transform(y['surface'])

# %%
def quaternion_to_euler(x, y, z, w):
    import math
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z

def elr(train):
    x, y, z, w = train['orientation_X'].tolist(), train['orientation_Y'].tolist(), train['orientation_Z'].tolist(), train['orientation_W'].tolist()
    nx, ny, nz = [], [], []
    for i in range(len(x)):
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx.append(xx)
        ny.append(yy)
        nz.append(zz)
    
    train['euler_x'] = nx
    train['euler_y'] = ny
    train['euler_z'] = nz
    return(train)    

train = elr(train)
test = elr(test)
train.head()
# Out:
#   row_id  series_id  measurement_number    ...      euler_x   euler_y   euler_z
# 0    0_0          0                   0    ...     2.843272 -0.024668  1.396664
# 1    0_1          0                   1    ...     2.843199 -0.024662  1.396646
# 2    0_2          0                   2    ...     2.843224 -0.024728  1.396682
# 3    0_3          0                   3    ...     2.843186 -0.024770  1.396721
# 4    0_4          0                   4    ...     2.843195 -0.024784  1.396693
#
# [5 rows x 17 columns]

# %%
def create_seg(train):
    segments = []

    for i in range(0, len(train), 128): 
        ox = train.orientation_X.values[i:i+128]
        oy = train.orientation_Y.values[i:i+128]
        oz = train.orientation_Z.values[i:i+128]
        ow = train.orientation_W.values[i:i+128]
        ax = train.angular_velocity_X.values[i:i+128]
        ay = train.angular_velocity_Y.values[i:i+128]
        az = train.angular_velocity_Z.values[i:i+128]
        lx = train.linear_acceleration_X.values[i:i+128]
        ly = train.linear_acceleration_Y.values[i:i+128]
        lz = train.linear_acceleration_Z.values[i:i+128]
        ex = train.euler_x.values[i:i+128]
        ey = train.euler_y.values[i:i+128]
        ez = train.euler_z.values[i:i+128]

        segments.append([ox, oy, oz, ow, ax, ay,az,lx, ly, lz, ex, ey, ez])
    segments = np.asarray(segments, dtype= np.float32).reshape(-1, 128, 13)
    return segments

# %%
seg = create_seg(train)
test = create_seg(test)

# %%
model = Sequential()
model.add(Conv1D(128, 1, input_shape = (128,13)))
model.add(Activation("relu"))
model.add(Conv1D(128,1))
model.add(Activation("relu"))
model.add(MaxPooling1D(pool_size=(2)))
model.add(Dropout(0.25))

model.add(Conv1D(64,3))
model.add(Activation("relu"))
model.add(Conv1D(64,3))
model.add(Activation("relu"))
model.add(MaxPooling1D(pool_size=(2)))
model.add(Dropout(0.25))

model.add(Conv1D(32,5))
model.add(Activation("relu"))
model.add(Conv1D(32,5))
model.add(Activation("relu"))
model.add(MaxPooling1D(pool_size=(2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(512))
model.add(Dropout(0.25))
model.add(Dense(9, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 128, 128)          1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 128, 128)          16512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128, 128)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 64, 128)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 62, 64)            24640
# _________________________________________________________________
# activation_3 (Activation)    (None, 62, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 60, 64)            12352
# _________________________________________________________________
# activation_4 (Activation)    (None, 60, 64)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 30, 64)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 64)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 26, 32)            10272
# _________________________________________________________________
# activation_5 (Activation)    (None, 26, 32)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 22, 32)            5152
# _________________________________________________________________
# activation_6 (Activation)    (None, 22, 32)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 11, 32)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 11, 32)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 352)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               180736
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 4617
# =================================================================
# Total params: 256,073
# Trainable params: 256,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
filepath = "skynet.hdf5"
callbacks_list = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=10), 
                 keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)]

model.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

history = model.fit(seg,
                      target,
                      batch_size=50,
                      epochs=100,
                      callbacks=callbacks_list,
                      validation_split=0.3,
                      shuffle=True,
                      verbose=1)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2667 samples, validate on 1143 samples
# Epoch 1/100
# 2667/2667 [==============================] - 4s 1ms/step - loss: 2.0071 - acc: 0.2231 - val_loss: 1.8433 - val_acc: 0.2485
#
# Epoch 00001: val_loss improved from inf to 1.84333, saving model to skynet.hdf5
# Epoch 2/100
# 2667/2667 [==============================] - 3s 964us/step - loss: 1.7948 - acc: 0.2958 - val_loss: 1.6787 - val_acc: 0.3272
#
# Epoch 00002: val_loss improved from 1.84333 to 1.67869, saving model to skynet.hdf5
# Epoch 3/100
# 2667/2667 [==============================] - 2s 929us/step - loss: 1.5973 - acc: 0.3708 - val_loss: 1.6384 - val_acc: 0.3123
#
# Epoch 00003: val_loss improved from 1.67869 to 1.63841, saving model to skynet.hdf5
# Epoch 4/100
# 2667/2667 [==============================] - 3s 939us/step - loss: 1.4701 - acc: 0.4537 - val_loss: 1.5288 - val_acc: 0.3850
#
# Epoch 00004: val_loss improved from 1.63841 to 1.52880, saving model to skynet.hdf5
# Epoch 5/100
# 2667/2667 [==============================] - 2s 931us/step - loss: 1.3940 - acc: 0.4724 - val_loss: 1.4691 - val_acc: 0.4051
#
# Epoch 00005: val_loss improved from 1.52880 to 1.46911, saving model to skynet.hdf5
# Epoch 6/100
# 2667/2667 [==============================] - 2s 921us/step - loss: 1.3377 - acc: 0.4976 - val_loss: 1.5346 - val_acc: 0.3736
#
# Epoch 00006: val_loss did not improve from 1.46911
# Epoch 7/100
# 2667/2667 [==============================] - 2s 918us/step - loss: 1.2787 - acc: 0.5227 - val_loss: 1.4822 - val_acc: 0.4191
#
# Epoch 00007: val_loss did not improve from 1.46911
# Epoch 8/100
# 2667/2667 [==============================] - 2s 926us/step - loss: 1.2262 - acc: 0.5486 - val_loss: 1.5146 - val_acc: 0.4217
#
# Epoch 00008: val_loss did not improve from 1.46911
# Epoch 9/100
# 2667/2667 [==============================] - 3s 975us/step - loss: 1.1975 - acc: 0.5598 - val_loss: 1.4793 - val_acc: 0.4173
#
# Epoch 00009: val_loss did not improve from 1.46911
# Epoch 10/100
# 2667/2667 [==============================] - 3s 981us/step - loss: 1.1619 - acc: 0.5879 - val_loss: 1.4959 - val_acc: 0.4217
#
# Epoch 00010: val_loss did not improve from 1.46911
# Epoch 11/100
# 2667/2667 [==============================] - 2s 912us/step - loss: 1.1036 - acc: 0.5962 - val_loss: 1.3299 - val_acc: 0.4759
#
# Epoch 00011: val_loss improved from 1.46911 to 1.32992, saving model to skynet.hdf5
# Epoch 12/100
# 2667/2667 [==============================] - 2s 913us/step - loss: 1.0538 - acc: 0.6187 - val_loss: 1.2691 - val_acc: 0.5101
#
# Epoch 00012: val_loss improved from 1.32992 to 1.26915, saving model to skynet.hdf5
# Epoch 13/100
# 2667/2667 [==============================] - 2s 930us/step - loss: 1.0315 - acc: 0.6284 - val_loss: 1.1724 - val_acc: 0.5214
#
# Epoch 00013: val_loss improved from 1.26915 to 1.17242, saving model to skynet.hdf5
# Epoch 14/100
# 2667/2667 [==============================] - 2s 921us/step - loss: 0.9861 - acc: 0.6397 - val_loss: 1.2099 - val_acc: 0.5363
#
# Epoch 00014: val_loss did not improve from 1.17242
# Epoch 15/100
# 2667/2667 [==============================] - 2s 933us/step - loss: 0.9407 - acc: 0.6629 - val_loss: 1.2056 - val_acc: 0.5276
#
# Epoch 00015: val_loss did not improve from 1.17242
# Epoch 16/100
# 2667/2667 [==============================] - 2s 921us/step - loss: 0.9219 - acc: 0.6640 - val_loss: 1.2108 - val_acc: 0.5398
#
# Epoch 00016: val_loss did not improve from 1.17242
# Epoch 17/100
# 2667/2667 [==============================] - 2s 924us/step - loss: 0.8889 - acc: 0.6790 - val_loss: 1.1502 - val_acc: 0.5451
#
# Epoch 00017: val_loss improved from 1.17242 to 1.15022, saving model to skynet.hdf5
# Epoch 18/100
# 2667/2667 [==============================] - 2s 923us/step - loss: 0.8431 - acc: 0.6952 - val_loss: 1.1076 - val_acc: 0.5862
#
# Epoch 00018: val_loss improved from 1.15022 to 1.10756, saving model to skynet.hdf5
# Epoch 19/100
# 2667/2667 [==============================] - 2s 918us/step - loss: 0.8110 - acc: 0.7000 - val_loss: 1.1432 - val_acc: 0.5617
#
# Epoch 00019: val_loss did not improve from 1.10756
# Epoch 20/100
# 2667/2667 [==============================] - 2s 929us/step - loss: 0.7912 - acc: 0.7008 - val_loss: 1.0527 - val_acc: 0.5923
#
# Epoch 00020: val_loss improved from 1.10756 to 1.05269, saving model to skynet.hdf5
# Epoch 21/100
# 2667/2667 [==============================] - 2s 929us/step - loss: 0.7968 - acc: 0.7105 - val_loss: 1.0352 - val_acc: 0.6002
#
# Epoch 00021: val_loss improved from 1.05269 to 1.03523, saving model to skynet.hdf5
# Epoch 22/100
# 2667/2667 [==============================] - 2s 919us/step - loss: 0.7607 - acc: 0.7173 - val_loss: 1.1090 - val_acc: 0.5818
#
# Epoch 00022: val_loss did not improve from 1.03523
# Epoch 23/100
# 2667/2667 [==============================] - 2s 915us/step - loss: 0.7239 - acc: 0.7379 - val_loss: 0.9975 - val_acc: 0.6352
#
# Epoch 00023: val_loss improved from 1.03523 to 0.99749, saving model to skynet.hdf5
# Epoch 24/100
# 2667/2667 [==============================] - 2s 921us/step - loss: 0.7080 - acc: 0.7450 - val_loss: 1.0580 - val_acc: 0.5879
#
# Epoch 00024: val_loss did not improve from 0.99749
# Epoch 25/100
# 2667/2667 [==============================] - 2s 921us/step - loss: 0.7206 - acc: 0.7417 - val_loss: 0.9764 - val_acc: 0.6282
#
# Epoch 00025: val_loss improved from 0.99749 to 0.97635, saving model to skynet.hdf5
# Epoch 26/100
# 2667/2667 [==============================] - 2s 926us/step - loss: 0.6223 - acc: 0.7657 - val_loss: 1.0294 - val_acc: 0.6010
#
# Epoch 00026: val_loss did not improve from 0.97635
# Epoch 27/100
# 2667/2667 [==============================] - 2s 920us/step - loss: 0.6412 - acc: 0.7653 - val_loss: 1.0789 - val_acc: 0.5862
#
# Epoch 00027: val_loss did not improve from 0.97635
# Epoch 28/100
# 2667/2667 [==============================] - 2s 916us/step - loss: 0.5994 - acc: 0.7773 - val_loss: 0.9668 - val_acc: 0.6387
#
# Epoch 00028: val_loss improved from 0.97635 to 0.96682, saving model to skynet.hdf5
# Epoch 29/100
# 2667/2667 [==============================] - 2s 912us/step - loss: 0.5933 - acc: 0.7878 - val_loss: 0.8966 - val_acc: 0.6737
#
# Epoch 00029: val_loss improved from 0.96682 to 0.89656, saving model to skynet.hdf5
# Epoch 30/100
# 2667/2667 [==============================] - 2s 914us/step - loss: 0.5625 - acc: 0.7859 - val_loss: 0.8861 - val_acc: 0.6807
#
# Epoch 00030: val_loss improved from 0.89656 to 0.88614, saving model to skynet.hdf5
# Epoch 31/100
# 2667/2667 [==============================] - 2s 920us/step - loss: 0.5748 - acc: 0.7942 - val_loss: 0.9419 - val_acc: 0.6702
#
# Epoch 00031: val_loss did not improve from 0.88614
# Epoch 32/100
# 2667/2667 [==============================] - 2s 914us/step - loss: 0.5527 - acc: 0.8024 - val_loss: 0.8614 - val_acc: 0.6955
#
# Epoch 00032: val_loss improved from 0.88614 to 0.86136, saving model to skynet.hdf5
# Epoch 33/100
# 2667/2667 [==============================] - 2s 925us/step - loss: 0.5508 - acc: 0.7942 - val_loss: 0.9726 - val_acc: 0.6395
#
# Epoch 00033: val_loss did not improve from 0.86136
# Epoch 34/100
# 2667/2667 [==============================] - 2s 920us/step - loss: 0.5161 - acc: 0.8129 - val_loss: 0.9744 - val_acc: 0.6684
#
# Epoch 00034: val_loss did not improve from 0.86136
# Epoch 35/100
# 2667/2667 [==============================] - 2s 916us/step - loss: 0.5256 - acc: 0.8005 - val_loss: 0.9576 - val_acc: 0.6649
#
# Epoch 00035: val_loss did not improve from 0.86136
# Epoch 36/100
# 2667/2667 [==============================] - 2s 927us/step - loss: 0.5314 - acc: 0.8088 - val_loss: 0.9397 - val_acc: 0.6772
#
# Epoch 00036: val_loss did not improve from 0.86136
# Epoch 37/100
# 2667/2667 [==============================] - 2s 922us/step - loss: 0.4879 - acc: 0.8260 - val_loss: 0.9714 - val_acc: 0.6824
#
# Epoch 00037: val_loss did not improve from 0.86136
# Epoch 38/100
# 2667/2667 [==============================] - 2s 921us/step - loss: 0.4932 - acc: 0.8226 - val_loss: 0.8301 - val_acc: 0.7200
#
# Epoch 00038: val_loss improved from 0.86136 to 0.83011, saving model to skynet.hdf5
# Epoch 39/100
# 2667/2667 [==============================] - 2s 924us/step - loss: 0.5081 - acc: 0.8140 - val_loss: 0.9107 - val_acc: 0.6684
#
# Epoch 00039: val_loss did not improve from 0.83011
# Epoch 40/100
# 2667/2667 [==============================] - 2s 917us/step - loss: 0.4681 - acc: 0.8294 - val_loss: 1.0025 - val_acc: 0.6448
#
# Epoch 00040: val_loss did not improve from 0.83011
# Epoch 41/100
# 2667/2667 [==============================] - 2s 920us/step - loss: 0.4640 - acc: 0.8283 - val_loss: 1.0773 - val_acc: 0.6457
#
# Epoch 00041: val_loss did not improve from 0.83011
# Epoch 42/100
# 2667/2667 [==============================] - 2s 914us/step - loss: 0.4336 - acc: 0.8481 - val_loss: 0.9291 - val_acc: 0.6833
#
# Epoch 00042: val_loss did not improve from 0.83011
# Epoch 43/100
# 2667/2667 [==============================] - 2s 919us/step - loss: 0.4588 - acc: 0.8279 - val_loss: 0.9763 - val_acc: 0.6842
#
# Epoch 00043: val_loss did not improve from 0.83011
# Epoch 44/100
# 2667/2667 [==============================] - 2s 917us/step - loss: 0.4561 - acc: 0.8290 - val_loss: 0.9003 - val_acc: 0.6894
#
# Epoch 00044: val_loss did not improve from 0.83011
# Epoch 45/100
# 2667/2667 [==============================] - 2s 913us/step - loss: 0.4350 - acc: 0.8470 - val_loss: 0.9282 - val_acc: 0.6754
#
# Epoch 00045: val_loss did not improve from 0.83011
# Epoch 46/100
# 2667/2667 [==============================] - 2s 911us/step - loss: 0.4207 - acc: 0.8463 - val_loss: 0.8172 - val_acc: 0.7157
#
# Epoch 00046: val_loss improved from 0.83011 to 0.81725, saving model to skynet.hdf5
# Epoch 47/100
# 2667/2667 [==============================] - 2s 919us/step - loss: 0.3942 - acc: 0.8515 - val_loss: 0.9714 - val_acc: 0.6850
#
# Epoch 00047: val_loss did not improve from 0.81725
# Epoch 48/100
# 2667/2667 [==============================] - 2s 911us/step - loss: 0.4139 - acc: 0.8511 - val_loss: 0.9262 - val_acc: 0.6885
#
# Epoch 00048: val_loss did not improve from 0.81725
# Epoch 49/100
# 2667/2667 [==============================] - 2s 920us/step - loss: 0.4293 - acc: 0.8406 - val_loss: 1.0873 - val_acc: 0.6562
#
# Epoch 00049: val_loss did not improve from 0.81725
# Epoch 50/100
# 2667/2667 [==============================] - 2s 923us/step - loss: 0.4257 - acc: 0.8485 - val_loss: 0.9238 - val_acc: 0.6912
#
# Epoch 00050: val_loss did not improve from 0.81725
# Epoch 51/100
# 2667/2667 [==============================] - 2s 917us/step - loss: 0.3913 - acc: 0.8575 - val_loss: 0.8807 - val_acc: 0.7139
#
# Epoch 00051: val_loss did not improve from 0.81725
# Epoch 52/100
# 2667/2667 [==============================] - 2s 923us/step - loss: 0.3727 - acc: 0.8643 - val_loss: 0.9988 - val_acc: 0.6868
#
# Epoch 00052: val_loss did not improve from 0.81725
# Epoch 53/100
# 2667/2667 [==============================] - 2s 911us/step - loss: 0.3674 - acc: 0.8706 - val_loss: 0.9754 - val_acc: 0.7043
#
# Epoch 00053: val_loss did not improve from 0.81725
# Epoch 54/100
# 2667/2667 [==============================] - 2s 924us/step - loss: 0.3451 - acc: 0.8718 - val_loss: 1.0667 - val_acc: 0.6745
#
# Epoch 00054: val_loss did not improve from 0.81725
# Epoch 55/100
# 2667/2667 [==============================] - 2s 915us/step - loss: 0.3525 - acc: 0.8763 - val_loss: 0.9046 - val_acc: 0.7200
#
# Epoch 00055: val_loss did not improve from 0.81725
# Epoch 56/100
# 2667/2667 [==============================] - 2s 920us/step - loss: 0.3293 - acc: 0.8808 - val_loss: 0.9219 - val_acc: 0.7139
#
# Epoch 00056: val_loss did not improve from 0.81725

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.load_weights(filepath)
predictions = model.predict(test)
prd = le.inverse_transform(predictions)
ss['surface'] = prd
ss.to_csv('submission.csv', index=False)
